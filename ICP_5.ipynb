# %%
from keras.layers import Input, Dense
from keras.models import Model

# this is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)
# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded)
# this model maps an input to its encoded representation
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
from keras.datasets import mnist, fashion_mnist
import numpy as np
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

autoencoder.fit(x_train, x_train,
                epochs=5,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/5
# 235/235 [==============================] - 9s 28ms/step - loss: 0.6941 - val_loss: 0.6941
# Epoch 2/5
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6940 - val_loss: 0.6940
# Epoch 3/5
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6939 - val_loss: 0.6939
# Epoch 4/5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6938 - val_loss: 0.6938
# Epoch 5/5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6938 - val_loss: 0.6937

# %%
from keras.layers import Input, Dense
from keras.models import Model

# Define the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))
# Encoded representation
encoded = Dense(128, activation='relu')(input_img)  # New hidden layer with 128 neurons
encoded = Dense(encoding_dim, activation='relu')(encoded)  # Encoding layer

# Decoded representation
decoded = Dense(128, activation='relu')(encoded)  # New hidden layer with 128 neurons
decoded = Dense(784, activation='sigmoid')(decoded)  # Decoding layer

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Compile autoencoder
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# Load and preprocess Fashion MNIST dataset
from keras.datasets import fashion_mnist
import numpy as np

(x_train, _), (x_test, _) = fashion_mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Train the autoencoder
autoencoder.fit(x_train, x_train,
                epochs=5,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
loss = autoencoder.evaluate(x_test, x_test)
print(f'Test loss: {loss}')
# Out:
# Epoch 1/5
# 235/235 [==============================] - 7s 25ms/step - loss: 0.6945 - val_loss: 0.6945
# Epoch 2/5
# 235/235 [==============================] - 5s 19ms/step - loss: 0.6944 - val_loss: 0.6944
# Epoch 3/5
# 235/235 [==============================] - 8s 34ms/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 4/5
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6942 - val_loss: 0.6942
# Epoch 5/5
# 235/235 [==============================] - 8s 34ms/step - loss: 0.6941 - val_loss: 0.6941
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6941
# Test loss: 0.6940664052963257

# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from keras.datasets import fashion_mnist
import numpy as np

# Define the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))
# Encoded representation
encoded = Dense(128, activation='relu')(input_img)  # New hidden layer with 128 neurons
encoded = Dense(encoding_dim, activation='relu')(encoded)  # Encoding layer

# Decoded representation
decoded = Dense(128, activation='relu')(encoded)  # New hidden layer with 128 neurons
decoded = Dense(784, activation='sigmoid')(decoded)  # Decoding layer

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Compile autoencoder with Adam optimizer and adjusted learning rate
autoencoder.compile(optimizer=Adam(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Load and preprocess Fashion MNIST dataset
(x_train, _), (x_test, _) = fashion_mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Train the autoencoder with adjusted batch size and number of epochs
history = autoencoder.fit(x_train, x_train,
                          epochs=15,  # Increased number of epochs
                          batch_size=128,  # Adjusted batch size
                          shuffle=True,
                          validation_data=(x_test, x_test))

# Evaluate performance on test data
loss, accuracy = autoencoder.evaluate(x_test, x_test)
print(f'Test loss: {loss:.4f}')
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/15
# 469/469 [==============================] - 16s 28ms/step - loss: 0.3447 - accuracy: 0.0110 - val_loss: 0.3056 - val_accuracy: 0.0156
# Epoch 2/15
# 469/469 [==============================] - 11s 23ms/step - loss: 0.2970 - accuracy: 0.0144 - val_loss: 0.2953 - val_accuracy: 0.0157
# Epoch 3/15
# 469/469 [==============================] - 14s 29ms/step - loss: 0.2894 - accuracy: 0.0170 - val_loss: 0.2891 - val_accuracy: 0.0209
# Epoch 4/15
# 469/469 [==============================] - 8s 17ms/step - loss: 0.2853 - accuracy: 0.0209 - val_loss: 0.2859 - val_accuracy: 0.0225
# Epoch 5/15
# 469/469 [==============================] - 5s 12ms/step - loss: 0.2827 - accuracy: 0.0227 - val_loss: 0.2839 - val_accuracy: 0.0216
# Epoch 6/15
# 469/469 [==============================] - 8s 17ms/step - loss: 0.2809 - accuracy: 0.0236 - val_loss: 0.2827 - val_accuracy: 0.0244
# Epoch 7/15
# 469/469 [==============================] - 8s 17ms/step - loss: 0.2795 - accuracy: 0.0249 - val_loss: 0.2812 - val_accuracy: 0.0264
# Epoch 8/15
# 469/469 [==============================] - 11s 23ms/step - loss: 0.2784 - accuracy: 0.0272 - val_loss: 0.2813 - val_accuracy: 0.0250
# Epoch 9/15
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2776 - accuracy: 0.0293 - val_loss: 0.2794 - val_accuracy: 0.0273
# Epoch 10/15
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2768 - accuracy: 0.0296 - val_loss: 0.2786 - val_accuracy: 0.0310
# Epoch 11/15
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2761 - accuracy: 0.0300 - val_loss: 0.2783 - val_accuracy: 0.0295
# Epoch 12/15
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2756 - accuracy: 0.0315 - val_loss: 0.2775 - val_accuracy: 0.0318
# Epoch 13/15
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2750 - accuracy: 0.0316 - val_loss: 0.2772 - val_accuracy: 0.0304
# Epoch 14/15
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2747 - accuracy: 0.0325 - val_loss: 0.2768 - val_accuracy: 0.0296
# Epoch 15/15
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2742 - accuracy: 0.0334 - val_loss: 0.2764 - val_accuracy: 0.0319
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2764 - accuracy: 0.0319
# Test loss: 0.2764

# %%
import matplotlib.pyplot as plt

# Predict on test data
decoded_imgs = autoencoder.predict(x_test)

# Number of images to display
num_images = 5

# Plot original images and reconstructed images
plt.figure(figsize=(10, 4))

for i in range(num_images):
    # Original images
    plt.subplot(2, num_images, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title('Original')
    plt.axis('off')

    # Reconstructed images
    plt.subplot(2, num_images, i + 1 + num_images)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    plt.title('Reconstructed')
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
from keras.layers import Input, Dense
from keras.models import Model

# Define the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))

# Encoder layers
encoded = Dense(128, activation='relu')(input_img)  # Add a hidden layer with 128 neurons
encoded = Dense(encoding_dim, activation='relu')(encoded)  # Encoding layer

# Decoder layers
decoded = Dense(128, activation='relu')(encoded)  # Add a hidden layer with 128 neurons
decoded = Dense(784, activation='sigmoid')(decoded)  # Decoding layer

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Compile the autoencoder
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# Load and preprocess Fashion MNIST dataset
from keras.datasets import fashion_mnist
import numpy as np

(x_train, _), (x_test, _) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Introducing noise to the data
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# Train the autoencoder
autoencoder.fit(x_train_noisy, x_train,
                epochs=10,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test_noisy, x_test_noisy))
# Out:
# Epoch 1/10
# 235/235 [==============================] - 6s 19ms/step - loss: 0.6971 - val_loss: 0.6970
# Epoch 2/10
# 235/235 [==============================] - 5s 22ms/step - loss: 0.6969 - val_loss: 0.6967
# Epoch 3/10
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6966 - val_loss: 0.6965
# Epoch 4/10
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6963 - val_loss: 0.6962
# Epoch 5/10
# 235/235 [==============================] - 5s 23ms/step - loss: 0.6961 - val_loss: 0.6960
# Epoch 6/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6958 - val_loss: 0.6957
# Epoch 7/10
# 235/235 [==============================] - 5s 20ms/step - loss: 0.6956 - val_loss: 0.6955
# Epoch 8/10
# 235/235 [==============================] - 5s 23ms/step - loss: 0.6953 - val_loss: 0.6952
# Epoch 9/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6951 - val_loss: 0.6950
# Epoch 10/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6949 - val_loss: 0.6948

# %%
from keras.layers import Input, Dense
from keras.models import Model

# Define the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))

# Encoder layers
encoded = Dense(256, activation='relu')(input_img)  # Add a hidden layer with 128 neurons
encoded = Dense(encoding_dim, activation='relu')(encoded)  # Encoding layer

# Decoder layers
decoded = Dense(256, activation='relu')(encoded)  # Add a hidden layer with 128 neurons
decoded = Dense(784, activation='sigmoid')(decoded)  # Decoding layer

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Compile the autoencoder
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# Load and preprocess Fashion MNIST dataset
from keras.datasets import fashion_mnist
import numpy as np

(x_train, _), (x_test, _) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Introducing noise to the data
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# Train the autoencoder
history = autoencoder.fit(x_train_noisy, x_train,
                          epochs=10,
                          batch_size=256,
                          shuffle=True,
                          validation_data=(x_test_noisy, x_test_noisy))
# Out:
# Epoch 1/10
# 235/235 [==============================] - 7s 27ms/step - loss: 0.6938 - val_loss: 0.6937
# Epoch 2/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.6936 - val_loss: 0.6935
# Epoch 3/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.6934 - val_loss: 0.6933
# Epoch 4/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.6932 - val_loss: 0.6931
# Epoch 5/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.6930 - val_loss: 0.6929
# Epoch 6/10
# 235/235 [==============================] - 7s 30ms/step - loss: 0.6928 - val_loss: 0.6927
# Epoch 7/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.6926 - val_loss: 0.6925
# Epoch 8/10
# 235/235 [==============================] - 7s 29ms/step - loss: 0.6924 - val_loss: 0.6923
# Epoch 9/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.6923 - val_loss: 0.6922
# Epoch 10/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.6921 - val_loss: 0.6920

# %%
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.models import Model
from keras.optimizers import Adam
from keras.datasets import fashion_mnist
import numpy as np

# Define the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))

# Encoder layers
encoded = Dense(512, activation='relu')(input_img)
encoded = BatchNormalization()(encoded)
encoded = Dense(encoding_dim, activation='relu')(encoded)

# Decoder layers
decoded = Dense(512, activation='relu')(encoded)
decoded = BatchNormalization()(decoded)
decoded = Dense(784, activation='sigmoid')(decoded)

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Compile the autoencoder
autoencoder.compile(optimizer=Adam(lr=0.001), loss='binary_crossentropy')

# Load and preprocess Fashion MNIST dataset
(x_train, _), (x_test, _) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Introducing noise to the data
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# Train the autoencoder
history = autoencoder.fit(x_train_noisy, x_train,
                          epochs=20,  # Increased epochs
                          batch_size=256,
                          shuffle=True,
                          validation_data=(x_test_noisy, x_test_noisy))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/20
# 235/235 [==============================] - 13s 50ms/step - loss: 0.3830 - val_loss: 0.2926
# Epoch 2/20
# 235/235 [==============================] - 11s 48ms/step - loss: 0.3016 - val_loss: 0.2735
# Epoch 3/20
# 235/235 [==============================] - 11s 48ms/step - loss: 0.2965 - val_loss: 0.2669
# Epoch 4/20
# 235/235 [==============================] - 10s 42ms/step - loss: 0.2939 - val_loss: 0.2623
# Epoch 5/20
# 235/235 [==============================] - 11s 48ms/step - loss: 0.2919 - val_loss: 0.2605
# Epoch 6/20
# 235/235 [==============================] - 11s 49ms/step - loss: 0.2903 - val_loss: 0.2582
# Epoch 7/20
# 235/235 [==============================] - 11s 49ms/step - loss: 0.2892 - val_loss: 0.2566
# Epoch 8/20
# 235/235 [==============================] - 12s 49ms/step - loss: 0.2882 - val_loss: 0.2556
# Epoch 9/20
# 235/235 [==============================] - 10s 41ms/step - loss: 0.2875 - val_loss: 0.2539
# Epoch 10/20
# 235/235 [==============================] - 11s 47ms/step - loss: 0.2868 - val_loss: 0.2534
# Epoch 11/20
# 235/235 [==============================] - 11s 48ms/step - loss: 0.2861 - val_loss: 0.2527
# Epoch 12/20
# 235/235 [==============================] - 11s 48ms/step - loss: 0.2855 - val_loss: 0.2523
# Epoch 13/20
# 235/235 [==============================] - 11s 46ms/step - loss: 0.2852 - val_loss: 0.2518
# Epoch 14/20
# 235/235 [==============================] - 10s 44ms/step - loss: 0.2847 - val_loss: 0.2521
# Epoch 15/20
# 235/235 [==============================] - 11s 47ms/step - loss: 0.2845 - val_loss: 0.2508
# Epoch 16/20
# 235/235 [==============================] - 11s 49ms/step - loss: 0.2838 - val_loss: 0.2505
# Epoch 17/20
# 235/235 [==============================] - 11s 48ms/step - loss: 0.2838 - val_loss: 0.2503
# Epoch 18/20
# 235/235 [==============================] - 10s 44ms/step - loss: 0.2834 - val_loss: 0.2497
# Epoch 19/20
# 235/235 [==============================] - 11s 45ms/step - loss: 0.2832 - val_loss: 0.2502
# Epoch 20/20
# 235/235 [==============================] - 11s 47ms/step - loss: 0.2828 - val_loss: 0.2496

# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import fashion_mnist
import numpy as np
import matplotlib.pyplot as plt

# Load data
(x_train, _), (x_test, _) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Define autoencoder with an additional hidden layer
encoding_dim = 32  # Compression factor
input_img = Input(shape=(784,))
encoded = Dense(128, activation='relu')(input_img)  # First hidden layer
encoded = Dense(encoding_dim, activation='relu')(encoded)  # Second hidden layer (encoding)
decoded = Dense(128, activation='relu')(encoded)  # First decoding layer
decoded = Dense(784, activation='sigmoid')(decoded)  # Output layer

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')  # Changed optimizer to Adam

# Train autoencoder
history = autoencoder.fit(x_train, x_train,
                          epochs=100,  # Increased epochs
                          batch_size=256,
                          shuffle=True,
                          validation_data=(x_test, x_test))

# Predict and visualize
decoded_imgs = autoencoder.predict(x_test)

# Visualize original and reconstructed images
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Reconstructed
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# Implement a denoising autoencoder
noise_factor = 0.2  # Reduced noise factor
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# Redefine autoencoder for denoising
input_img_noisy = Input(shape=(784,))
encoded_noisy = Dense(128, activation='relu')(input_img_noisy)
encoded_noisy = Dense(encoding_dim, activation='relu')(encoded_noisy)
decoded_noisy = Dense(128, activation='relu')(encoded_noisy)
decoded_noisy = Dense(784, activation='sigmoid')(decoded_noisy)

denoising_autoencoder = Model(input_img_noisy, decoded_noisy)
denoising_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')  # Changed optimizer to Adam

# Train denoising autoencoder
history_denoising = denoising_autoencoder.fit(x_train_noisy, x_train,
                                              epochs=100,  # Increased epochs
                                              batch_size=256,
                                              shuffle=True,
                                              validation_data=(x_test_noisy, x_test))

# Predict and visualize denoised images
denoised_imgs = denoising_autoencoder.predict(x_test_noisy)

plt.figure(figsize=(20, 4))
for i in range(n):
    # Noisy image
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Reconstructed image
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(denoised_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# Plot loss and accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_denoising.history['loss'], label='Denoising Training Loss')
plt.plot(history_denoising.history['val_loss'], label='Denoising Validation Loss')
plt.title('Denoising Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/100
# 235/235 [==============================] - 5s 18ms/step - loss: 0.3720 - val_loss: 0.3165
# Epoch 2/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.3049 - val_loss: 0.3019
# Epoch 3/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2962 - val_loss: 0.2953
# Epoch 4/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2915 - val_loss: 0.2919
# Epoch 5/100
# 235/235 [==============================] - 6s 26ms/step - loss: 0.2888 - val_loss: 0.2896
# Epoch 6/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2866 - val_loss: 0.2892
# Epoch 7/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2850 - val_loss: 0.2863
# Epoch 8/100
# 235/235 [==============================] - 6s 25ms/step - loss: 0.2837 - val_loss: 0.2853
# Epoch 9/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2825 - val_loss: 0.2842
# Epoch 10/100
# 235/235 [==============================] - 6s 25ms/step - loss: 0.2815 - val_loss: 0.2833
# Epoch 11/100
# 235/235 [==============================] - 7s 31ms/step - loss: 0.2808 - val_loss: 0.2826
# Epoch 12/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2799 - val_loss: 0.2819
# Epoch 13/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2794 - val_loss: 0.2814
# Epoch 14/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2789 - val_loss: 0.2808
# Epoch 15/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2783 - val_loss: 0.2804
# Epoch 16/100
# 235/235 [==============================] - 6s 24ms/step - loss: 0.2779 - val_loss: 0.2801
# Epoch 17/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2774 - val_loss: 0.2796
# Epoch 18/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2771 - val_loss: 0.2792
# Epoch 19/100
# 235/235 [==============================] - 6s 25ms/step - loss: 0.2768 - val_loss: 0.2793
# Epoch 20/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2765 - val_loss: 0.2793
# Epoch 21/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2762 - val_loss: 0.2785
# Epoch 22/100
# 235/235 [==============================] - 6s 25ms/step - loss: 0.2759 - val_loss: 0.2782
# Epoch 23/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2757 - val_loss: 0.2778
# Epoch 24/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2754 - val_loss: 0.2778
# Epoch 25/100
# 235/235 [==============================] - 6s 24ms/step - loss: 0.2752 - val_loss: 0.2778
# Epoch 26/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2751 - val_loss: 0.2774
# Epoch 27/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2749 - val_loss: 0.2772
# Epoch 28/100
# 235/235 [==============================] - 6s 24ms/step - loss: 0.2747 - val_loss: 0.2769
# Epoch 29/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2745 - val_loss: 0.2767
# Epoch 30/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2743 - val_loss: 0.2768
# Epoch 31/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2741 - val_loss: 0.2765
# Epoch 32/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2740 - val_loss: 0.2768
# Epoch 33/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2739 - val_loss: 0.2762
# Epoch 34/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2738 - val_loss: 0.2761
# Epoch 35/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2736 - val_loss: 0.2763
# Epoch 36/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2735 - val_loss: 0.2760
# Epoch 37/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2735 - val_loss: 0.2759
# Epoch 38/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2733 - val_loss: 0.2759
# Epoch 39/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2732 - val_loss: 0.2757
# Epoch 40/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2731 - val_loss: 0.2756
# Epoch 41/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2731 - val_loss: 0.2755
# Epoch 42/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2729 - val_loss: 0.2754
# Epoch 43/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2729 - val_loss: 0.2753
# Epoch 44/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2728 - val_loss: 0.2754
# Epoch 45/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2728 - val_loss: 0.2755
# Epoch 46/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2727 - val_loss: 0.2751
# Epoch 47/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2726 - val_loss: 0.2751
# Epoch 48/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2725 - val_loss: 0.2751
# Epoch 49/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2725 - val_loss: 0.2756
# Epoch 50/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2724 - val_loss: 0.2749
# Epoch 51/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2724 - val_loss: 0.2750
# Epoch 52/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2723 - val_loss: 0.2748
# Epoch 53/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2722 - val_loss: 0.2748
# Epoch 54/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2722 - val_loss: 0.2748
# Epoch 55/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2721 - val_loss: 0.2747
# Epoch 56/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2721 - val_loss: 0.2747
# Epoch 57/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2721 - val_loss: 0.2745
# Epoch 58/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2720 - val_loss: 0.2745
# Epoch 59/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2719 - val_loss: 0.2745
# Epoch 60/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2719 - val_loss: 0.2744
# Epoch 61/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2718 - val_loss: 0.2744
# Epoch 62/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2718 - val_loss: 0.2744
# Epoch 63/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2717 - val_loss: 0.2745
# Epoch 64/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2718 - val_loss: 0.2743
# Epoch 65/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2717 - val_loss: 0.2745
# Epoch 66/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2717 - val_loss: 0.2743
# Epoch 67/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2716 - val_loss: 0.2742
# Epoch 68/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2715 - val_loss: 0.2741
# Epoch 69/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2715 - val_loss: 0.2741
# Epoch 70/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2715 - val_loss: 0.2741
# Epoch 71/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2714 - val_loss: 0.2740
# Epoch 72/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2714 - val_loss: 0.2741
# Epoch 73/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2713 - val_loss: 0.2740
# Epoch 74/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2714 - val_loss: 0.2739
# Epoch 75/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2713 - val_loss: 0.2739
# Epoch 76/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2713 - val_loss: 0.2739
# Epoch 77/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2712 - val_loss: 0.2740
# Epoch 78/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2711 - val_loss: 0.2738
# Epoch 79/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2711 - val_loss: 0.2738
# Epoch 80/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2711 - val_loss: 0.2736
# Epoch 81/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2710 - val_loss: 0.2735
# Epoch 82/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2709 - val_loss: 0.2736
# Epoch 83/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2709 - val_loss: 0.2736
# Epoch 84/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2709 - val_loss: 0.2735
# Epoch 85/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2709 - val_loss: 0.2735
# Epoch 86/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2708 - val_loss: 0.2735
# Epoch 87/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2708 - val_loss: 0.2734
# Epoch 88/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2708 - val_loss: 0.2734
# Epoch 89/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2708 - val_loss: 0.2734
# Epoch 90/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2708 - val_loss: 0.2733
# Epoch 91/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2707 - val_loss: 0.2734
# Epoch 92/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2707 - val_loss: 0.2734
# Epoch 93/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2707 - val_loss: 0.2733
# Epoch 94/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2706 - val_loss: 0.2733
# Epoch 95/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2706 - val_loss: 0.2732
# Epoch 96/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2706 - val_loss: 0.2732
# Epoch 97/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2706 - val_loss: 0.2734
# Epoch 98/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2705 - val_loss: 0.2732
# Epoch 99/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2705 - val_loss: 0.2734
# Epoch 100/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2705 - val_loss: 0.2731
# 313/313 [==============================] - 1s 4ms/step
# Epoch 1/100
# 235/235 [==============================] - 5s 17ms/step - loss: 0.3729 - val_loss: 0.3204
# Epoch 2/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.3109 - val_loss: 0.3074
# Epoch 3/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3017 - val_loss: 0.3010
# Epoch 4/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2970 - val_loss: 0.2972
# Epoch 5/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2937 - val_loss: 0.2947
# Epoch 6/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2913 - val_loss: 0.2926
# Epoch 7/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2895 - val_loss: 0.2909
# Epoch 8/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2880 - val_loss: 0.2899
# Epoch 9/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2869 - val_loss: 0.2889
# Epoch 10/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2861 - val_loss: 0.2881
# Epoch 11/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2852 - val_loss: 0.2875
# Epoch 12/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2845 - val_loss: 0.2867
# Epoch 13/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2840 - val_loss: 0.2862
# Epoch 14/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2835 - val_loss: 0.2859
# Epoch 15/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2830 - val_loss: 0.2854
# Epoch 16/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2827 - val_loss: 0.2854
# Epoch 17/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2822 - val_loss: 0.2847
# Epoch 18/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2819 - val_loss: 0.2845
# Epoch 19/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2816 - val_loss: 0.2842
# Epoch 20/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2813 - val_loss: 0.2841
# Epoch 21/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2811 - val_loss: 0.2837
# Epoch 22/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2808 - val_loss: 0.2835
# Epoch 23/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2806 - val_loss: 0.2837
# Epoch 24/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2804 - val_loss: 0.2831
# Epoch 25/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2802 - val_loss: 0.2831
# Epoch 26/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2800 - val_loss: 0.2828
# Epoch 27/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2799 - val_loss: 0.2826
# Epoch 28/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2797 - val_loss: 0.2824
# Epoch 29/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2795 - val_loss: 0.2824
# Epoch 30/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2793 - val_loss: 0.2821
# Epoch 31/100
# 235/235 [==============================] - 8s 35ms/step - loss: 0.2792 - val_loss: 0.2824
# Epoch 32/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2791 - val_loss: 0.2819
# Epoch 33/100
# 235/235 [==============================] - 7s 30ms/step - loss: 0.2789 - val_loss: 0.2819
# Epoch 34/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2789 - val_loss: 0.2817
# Epoch 35/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2788 - val_loss: 0.2815
# Epoch 36/100
# 235/235 [==============================] - 6s 24ms/step - loss: 0.2786 - val_loss: 0.2815
# Epoch 37/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2786 - val_loss: 0.2815
# Epoch 38/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2784 - val_loss: 0.2816
# Epoch 39/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2783 - val_loss: 0.2813
# Epoch 40/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2782 - val_loss: 0.2816
# Epoch 41/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2782 - val_loss: 0.2814
# Epoch 42/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2781 - val_loss: 0.2811
# Epoch 43/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2780 - val_loss: 0.2810
# Epoch 44/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2779 - val_loss: 0.2808
# Epoch 45/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2778 - val_loss: 0.2809
# Epoch 46/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2777 - val_loss: 0.2808
# Epoch 47/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2777 - val_loss: 0.2807
# Epoch 48/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2776 - val_loss: 0.2807
# Epoch 49/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2775 - val_loss: 0.2806
# Epoch 50/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2775 - val_loss: 0.2805
# Epoch 51/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2774 - val_loss: 0.2805
# Epoch 52/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2773 - val_loss: 0.2805
# Epoch 53/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2773 - val_loss: 0.2804
# Epoch 54/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2772 - val_loss: 0.2803
# Epoch 55/100
# 235/235 [==============================] - 6s 26ms/step - loss: 0.2772 - val_loss: 0.2809
# Epoch 56/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2771 - val_loss: 0.2803
# Epoch 57/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2771 - val_loss: 0.2803
# Epoch 58/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2771 - val_loss: 0.2807
# Epoch 59/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2770 - val_loss: 0.2803
# Epoch 60/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2769 - val_loss: 0.2802
# Epoch 61/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2769 - val_loss: 0.2801
# Epoch 62/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2768 - val_loss: 0.2800
# Epoch 63/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2768 - val_loss: 0.2803
# Epoch 64/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2768 - val_loss: 0.2799
# Epoch 65/100
# 235/235 [==============================] - 6s 27ms/step - loss: 0.2767 - val_loss: 0.2800
# Epoch 66/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2767 - val_loss: 0.2799
# Epoch 67/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2766 - val_loss: 0.2799
# Epoch 68/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2766 - val_loss: 0.2798
# Epoch 69/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2765 - val_loss: 0.2798
# Epoch 70/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2765 - val_loss: 0.2798
# Epoch 71/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2765 - val_loss: 0.2797
# Epoch 72/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2764 - val_loss: 0.2796
# Epoch 73/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2764 - val_loss: 0.2796
# Epoch 74/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2764 - val_loss: 0.2798
# Epoch 75/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2763 - val_loss: 0.2796
# Epoch 76/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2763 - val_loss: 0.2796
# Epoch 77/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2763 - val_loss: 0.2795
# Epoch 78/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2762 - val_loss: 0.2796
# Epoch 79/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2762 - val_loss: 0.2799
# Epoch 80/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2762 - val_loss: 0.2796
# Epoch 81/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2761 - val_loss: 0.2795
# Epoch 82/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2761 - val_loss: 0.2794
# Epoch 83/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2761 - val_loss: 0.2795
# Epoch 84/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2761 - val_loss: 0.2793
# Epoch 85/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2760 - val_loss: 0.2794
# Epoch 86/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2760 - val_loss: 0.2794
# Epoch 87/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2760 - val_loss: 0.2793
# Epoch 88/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2759 - val_loss: 0.2795
# Epoch 89/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2759 - val_loss: 0.2793
# Epoch 90/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2759 - val_loss: 0.2792
# Epoch 91/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2759 - val_loss: 0.2791
# Epoch 92/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2758 - val_loss: 0.2792
# Epoch 93/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2758 - val_loss: 0.2793
# Epoch 94/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2758 - val_loss: 0.2792
# Epoch 95/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2758 - val_loss: 0.2792
# Epoch 96/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2757 - val_loss: 0.2792
# Epoch 97/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2757 - val_loss: 0.2790
# Epoch 98/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2757 - val_loss: 0.2793
# Epoch 99/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2757 - val_loss: 0.2792
# Epoch 100/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2757 - val_loss: 0.2789
# 313/313 [==============================] - 1s 3ms/step
